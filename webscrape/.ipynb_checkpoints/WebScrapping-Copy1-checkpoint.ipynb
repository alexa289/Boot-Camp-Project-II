# %%
#Import Dependencies
import pandas as pd
import time
from bs4 import BeautifulSoup #as bs
import requests as req
from splinter import Browser
from selenium import webdriver
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.wine_store_db
collection = db.items

# %%
db.items.find().count()
# Out:
# 0

# %%
# clear test run data from mongodb 
# collection.delete_many();
db.items.delete_many({});
db.items.find().count()
# Out:
# 0

# %%
def scrape_wine():
    browser = webdriver.Chrome('chromedriver.exe')
    news = {}
    mainurl = 'https://www.binnys.com' 
    
    start = "https://www.binnys.com/wine/"
    
    browser.get(start)
    time.sleep(1)
    
    html = browser.page_source 
    soup = BeautifulSoup(html, "html.parser")

    pages = int(522)
    
       
    for page in range(1, pages):
                # Error handling
        try:

            print(page)
            if page == 1:
                url = start
                browser.get(url)
                time.sleep(1)

                html = browser.page_source 
                soup = BeautifulSoup(html, "html.parser")

                alldivs = ''
                alldivs = soup.find_all('div',class_='row result')

        #          
#                 print(url)
        #         print(alldivs)

                for alldiv in alldivs:

                    # Get Wine name 
                    title = alldiv.find("h3", class_="title").get_text()
#                     print(title)
                    title_new = replace(title,'\n','')
                    print(title_new)
                    # Get URL for wine image
                    image = alldiv.find('img', class_="prodImg")
        #             image = alldiv.find("img", class_= 'prodImg').get_text()
#                     print(image['src'])
                    imageurl = image['src']
                    print(imageurl)
        
                    # Get url for wine page             
                    for imgspacer in alldiv.find_all('div', class_="imageSpacer"):
                        for a in imgspacer.find_all('a', class_='hawkLink',href=True):
                            wineurl = mainurl + a['href']
#                             print(wineurl)

#                     Dictionary to be inserted as a MongoDB document
                        post = {
                          'title': title,
                          'image': imageurl,
                          'wineurl': wineurl,
                          }
                                
                        collection.insert_one(post)

            else:
                url = "https://www.binnys.com/wine//" + str(page) + "#"
                browser.get(url)
                time.sleep(1)

                html = browser.page_source 
                soup = BeautifulSoup(html, "html.parser")

                alldivs = ''
                alldivs = soup.find_all('div',class_='row result')

        #          
#                 print(url)
        #         print(alldivs)

                for alldiv in alldivs:
                    # Get Wine name 
                    title = alldiv.find("h3", class_="title").get_text()
#                     print(title)

                    # Get URL for wine image
                    image = alldiv.find('img', class_="prodImg")
        #             image = alldiv.find("img", class_= 'prodImg').get_text()
#                     print(image['src'])
                    imageurl = image['src']
                    print(imageurl)

                    # Get url for wine page             
                    for imgspacer in alldiv.find_all('div', class_="imageSpacer"):
                        for a in imgspacer.find_all('a', class_='hawkLink',href=True):
                            wineurl = mainurl + a['href']
#                             print(wineurl)

#                     Dictionary to be inserted as a MongoDB document
                        post = {
                          'title': title,
                          'image': imageurl,
                          'wineurl': wineurl,
                          }
                        

                        collection.insert_one(post)
      
        except Exception as e:
            print(e)        


scrape_wine()
# Out:
# 1
# https://s3imgcdn.binnys.com/images/prodimages/83531L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/57542L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/35433L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/47224L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/419201L.jpg
# https://s3imgcdn.binnys.com/images/prodimages/256440L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/231013L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/12020L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/48160L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/12013L.jpg
# https://s3imgcdn.binnys.com/images/prodimages/16251L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/250229L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/36103L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/54156L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/30855L.jpg
# https://s3imgcdn.binnys.com/images/winelabels/373401L.jpg
# ...

# %%
for post in db.items.find():
    print(post)
# Out:
# {'_id': ObjectId('5b14a57cbb4c98a9e46c2fa7'), 'title': '\nMija Red Sangria\n', 'image': 'https://s3imgcdn.binnys.com/images/prodimages/83531L.jpg', 'wineurl': 'https://www.binnys.com/wine/Mija_Red_Sangria_83531.html'}
# {'_id': ObjectId('5b14a57cbb4c98a9e46c2fa8'), 'title': '\nAntinori Santa Cristina Toscano Rosso\n', 'image': 'https://s3imgcdn.binnys.com/images/winelabels/57542L.jpg', 'wineurl': 'https://www.binnys.com/wine/Antinori_Santa_Cristina_Toscano_Rosso_57542.html'}
# {'_id': ObjectId('5b14a57cbb4c98a9e46c2fa9'), 'title': '\nStella Rosa Rosso by il Conte\n', 'image': 'https://s3imgcdn.binnys.com/images/winelabels/35433L.jpg', 'wineurl': 'https://www.binnys.com/wine/Stella_Rosa_Rosso_by_il_Conte_35433.html'}
# {'_id': ObjectId('5b14a57cbb4c98a9e46c2faa'), 'title': '\nBarefoot Moscato\n', 'image': 'https://s3imgcdn.binnys.com/images/winelabels/47224L.jpg', 'wineurl': 'https://www.binnys.com/wine/Barefoot_Moscato_47224.html'}
# ...

# %%
db.items.find().count()
# 12301
# Out:
# 12301

# %%
for doc in db.items.find().sort('title', pymongo.ASCENDING):
    print(doc)
# Out:
# {'_id': ObjectId('5b14cb47bb4c98a9e46c3e9c'), 'title': '\n1927 Alvear Pedro Ximenez Solera 1927\n', 'image': 'https://s3imgcdn.binnys.com/images/winelabels/320032L.jpg', 'wineurl': 'https://www.binnys.com/wine/Alvear_Pedro_Ximenez_Solera_1927_320032.html'}
# {'_id': ObjectId('5b1532eebb4c98a9e46c5f8e'), 'title': '\n1977 Niepoort Garrafeira Vintage Port\n', 'image': 'https://s3imgcdn.binnys.com/images/winelabels/46008L.jpg', 'wineurl': 'https://www.binnys.com/wine/Niepoort_Garrafeira_Vintage_Port_46008.html'}
# {'_id': ObjectId('5b15325abb4c98a9e46c5be5'), 'title': '\n1978 Chateau Lafite Rothschild Pauillac\n', 'image': 'https://s3imgcdn.binnys.com/images/winelabels/32940L.jpg', 'wineurl': 'https://www.binnys.com/wine/Chateau_Lafite_Rothschild_Pauillac_32940.html'}
# ...

# %%
# Search  FUll Title
# this one works - full title !!!!!!!
list(db.items.find({'title':'\nBeringer California Collection Merlot\n'}))
# Out:
# [{'_id': ObjectId('5b14c9e6bb4c98a9e46c346d'),
#   'image': 'https://s3imgcdn.binnys.com/images/prodimages/953258L.jpg',
#   'title': '\nBeringer California Collection Merlot\n',
#   'wineurl': 'https://www.binnys.com/wine/Beringer_California_Collection_Merlot_953258.html'},
#  {'_id': ObjectId('5b14ce70bb4c98a9e46c56d1'),
#   'image': 'https://s3imgcdn.binnys.com/images/winelabels/12006L.jpg',
#   'title': '\nBeringer California Collection Merlot\n',
#   'wineurl': 'https://www.binnys.com/wine/Beringer_California_Collection_Merlot_12006.html'}]

# %%
# Search Fuzzy Match 
# This works Fuzzy Match

list(db.items.find({'title': {'$regex': 'Rainwater'}}))
# Out:
# [{'_id': ObjectId('5b14c962bb4c98a9e46c303a'),
#   'image': 'https://s3imgcdn.binnys.com/images/prodimages/330048L.jpg',
#   'title': '\nBroadbent Rainwater Madeira\n',
#   'wineurl': 'https://www.binnys.com/wine/Broadbent_Rainwater_Madeira_330048.html'},
#  {'_id': ObjectId('5b14cbe4bb4c98a9e46c42b7'),
#   'image': 'https://s3imgcdn.binnys.com/images/winelabels/58856L.jpg',
#   'title': '\nRare Wine Company Barbeito Historic Series Baltimore Rainwater\n',
#   'wineurl': 'https://www.binnys.com/wine/Rare_Wine_Company_Barbeito_Historic_Series_Baltimore_Rainwater_58856.html'},
#  {'_id': ObjectId('5b14cc09bb4c98a9e46c43fb'),
#   'image': 'https://s3imgcdn.binnys.com/images/prodimages/331137L.jpg',
#   'title': '\nMiles Rainwater Madeira\n',
#   'wineurl': 'https://www.binnys.com/wine/Miles_Rainwater_Madeira_331137.html'},
#  {'_id': ObjectId('5b14cd82bb4c98a9e46c4f6e'),
#   'image': 'https://s3imgcdn.binnys.com/images/prodimages/10746L.jpg',
# ...

# %%
# add rows into Heroku MongoDB server mongodb://heroku_89070zm5:vsvftlk81u1jbu8aaq0kf5se8l@ds151840.mlab.com:51840/heroku_89070zm5
